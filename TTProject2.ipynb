# %% [markdown]
# <a href="https://colab.research.google.com/github/aruna-ss/Techtable-Project-one/blob/master/TTProject2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
#  LOGISTIC REGRESSION

# %%
df1=pd.read_csv("test_AV3.csv")
df1.head(50)
df=df1.dropna(axis=0)
df
# Out:
#       Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0    LP001015   Male     Yes  ...            1.0         Urban           Y
# 1    LP001022   Male     Yes  ...            1.0         Urban           Y
# 2    LP001031   Male     Yes  ...            1.0         Urban           Y
# 4    LP001051   Male      No  ...            1.0         Urban           Y
# 5    LP001054   Male     Yes  ...            1.0         Urban           Y
# ..        ...    ...     ...  ...            ...           ...         ...
# 361  LP002969   Male     Yes  ...            1.0     Semiurban           Y
# 362  LP002971   Male     Yes  ...            1.0         Urban           Y
# 363  LP002975   Male     Yes  ...            1.0         Urban           Y
# 365  LP002986   Male     Yes  ...            1.0         Rural           Y
# 366  LP002989   Male      No  ...            1.0         Rural           Y
#
# [289 rows x 13 columns]

# %%
plt.scatter(df.LoanAmount,df.Loan_Status,marker='.',color='green')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['LoanAmount']],df.Loan_Status,train_size=0.9)

# %%
X_test
# Out:
#      LoanAmount
# 346       133.0
# 280       122.0
# 274        94.0
# 194       412.0
# 266       112.0
# 353       120.0
# 63        108.0
# 201        90.0
# 291       145.0
# 68        187.0
# 238       107.0
# 337       119.0
# 159       143.0
# 131       132.0
# 190       132.0
# 178       143.0
# 133        90.0
# 50        124.0
# 42         90.0
# 314       134.0
# 252       131.0
# 130       124.0
# 355       197.0
# 316       120.0
# 234       104.0
# 298       117.0
# 97        140.0
# 271       212.0
# 66        135.0

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.15187894, 0.84812106],
#        [0.14860452, 0.85139548],
#        [0.14053235, 0.85946765],
#        [0.25551748, 0.74448252],
#        [0.14567854, 0.85432146],
#        [0.14801547, 0.85198453],
#        [0.1445216 , 0.8554784 ],
#        [0.13940961, 0.86059039],
#        [0.15551834, 0.84448166],
#        [0.16881787, 0.83118213],
#        [0.14423356, 0.85576644],
#        [0.14772167, 0.85227833],
#        [0.15490687, 0.84509313],
#        [0.15157883, 0.84842117],
#        [0.15157883, 0.84842117],
#        [0.15490687, 0.84509313],
#        [0.13940961, 0.86059039],
#        [0.1491955 , 0.8508045 ],
#        [0.13940961, 0.86059039],
#        [0.15217953, 0.84782047],
#        [0.15127921, 0.84872079],
#        [0.1491955 , 0.8508045 ],
#        [0.17211497, 0.82788503],
#        [0.14801547, 0.85198453],
#        [0.1433723 , 0.8566277 ],
#        [0.14713551, 0.85286449],
#        [0.15399335, 0.84600665],
#        [0.17715595, 0.82284405],
# ...

# %%
model.score(X_test,y_test)
# Out:
# 0.8275862068965517

# %% [markdown]
# DECISION TREE

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df2=pd.read_csv("test_AV3.csv")
df3=df2.dropna(axis=1)
df3.head(50)
# Out:
#      Loan_ID Married     Education  ...  CoapplicantIncome  Property_Area Loan_Status
# 0   LP001015     Yes      Graduate  ...                  0          Urban           Y
# 1   LP001022     Yes      Graduate  ...               1500          Urban           Y
# 2   LP001031     Yes      Graduate  ...               1800          Urban           Y
# 3   LP001035     Yes      Graduate  ...               2546          Urban           Y
# 4   LP001051      No  Not Graduate  ...                  0          Urban           Y
# 5   LP001054     Yes  Not Graduate  ...               3422          Urban           Y
# 6   LP001055      No  Not Graduate  ...                  0      Semiurban           Y
# 7   LP001056     Yes  Not Graduate  ...                  0          Rural           N
# 8   LP001059     Yes      Graduate  ...                  0          Urban           Y
# 9   LP001067      No  Not Graduate  ...               2400      Semiurban           Y
# ...

# %%
 inputs = df3.drop('Loan_Status',axis='columns')

# %%
target =df3.Loan_Status
target
# Out:
# 0      Y
# 1      Y
# 2      Y
# 3      Y
# 4      Y
#       ..
# 362    Y
# 363    Y
# 364    Y
# 365    Y
# 366    Y
# Name: Loan_Status, Length: 367, dtype: object

# %%
 from sklearn.preprocessing import LabelEncoder
le_Loan_ID= LabelEncoder()
le_Married= LabelEncoder()
le_Education= LabelEncoder()
le_ApplicantIncome= LabelEncoder()
le_CoapplicantIncome= LabelEncoder()
le_LoanAmount= LabelEncoder()
le_Property_Area=LabelEncoder()

# %%
inputs['Loan_ID_n'] = le_Loan_ID.fit_transform(inputs['Loan_ID'])
inputs['Married_n'] = le_Married.fit_transform(inputs['Married'])
inputs['Education_n'] = le_Education.fit_transform(inputs['Education'])
inputs['ApplicantIncome_n'] = le_ApplicantIncome.fit_transform(inputs['ApplicantIncome'])
inputs['CoapplicantIncome_n'] = le_CoapplicantIncome.fit_transform(inputs['CoapplicantIncome'])
inputs['Property_Area_n'] = le_Property_Area.fit_transform(inputs['Property_Area'])

# %%
inputs
# Out:
#       Loan_ID Married  ... CoapplicantIncome_n  Property_Area_n
# 0    LP001015     Yes  ...                   0                2
# 1    LP001022     Yes  ...                  43                2
# 2    LP001031     Yes  ...                  67                2
# 3    LP001035     Yes  ...                 110                2
# 4    LP001051      No  ...                   0                2
# ..        ...     ...  ...                 ...              ...
# 362  LP002971     Yes  ...                  65                2
# 363  LP002975     Yes  ...                  12                2
# 364  LP002980      No  ...                  75                1
# 365  LP002986     Yes  ...                 101                0
# 366  LP002989      No  ...                   0                0
#
# [367 rows x 12 columns]

# %%
inputs_n=inputs.drop(['ApplicantIncome','CoapplicantIncome','Loan_ID','Education','Married','Property_Area'],axis='columns')
inputs_n
# Out:
#      Loan_ID_n  Married_n  ...  CoapplicantIncome_n  Property_Area_n
# 0            0          1  ...                    0                2
# 1            1          1  ...                   43                2
# 2            2          1  ...                   67                2
# 3            3          1  ...                  110                2
# 4            4          0  ...                    0                2
# ..         ...        ...  ...                  ...              ...
# 362        362          1  ...                   65                2
# 363        363          1  ...                   12                2
# 364        364          0  ...                   75                1
# 365        365          1  ...                  101                0
# 366        366          0  ...                    0                0
#
# [367 rows x 6 columns]

# %%
 from sklearn.model_selection import train_test_split

# %%
 x_train,x_test,y_train,y_test=train_test_split(inputs_n,target,train_size=0.80)

# %%
 from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
 model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
 model.score(x_test,y_test)
# Out:
# 0.7567567567567568

# %%
y_test
# Out:
# 159    Y
# 34     Y
# 357    Y
# 248    Y
# 338    Y
#       ..
# 81     Y
# 239    Y
# 325    Y
# 348    Y
# 68     Y
# Name: Loan_Status, Length: 74, dtype: object

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
 import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris

# %%
df4=pd.read_csv('test_AV3.csv')
df4.head(50)
# Out:
#      Loan_ID  Gender Married  ... Credit_History Property_Area Loan_Status
# 0   LP001015    Male     Yes  ...            1.0         Urban           Y
# 1   LP001022    Male     Yes  ...            1.0         Urban           Y
# 2   LP001031    Male     Yes  ...            1.0         Urban           Y
# 3   LP001035    Male     Yes  ...            NaN         Urban           Y
# 4   LP001051    Male      No  ...            1.0         Urban           Y
# 5   LP001054    Male     Yes  ...            1.0         Urban           Y
# 6   LP001055  Female      No  ...            1.0     Semiurban           Y
# 7   LP001056    Male     Yes  ...            0.0         Rural           N
# 8   LP001059    Male     Yes  ...            1.0         Urban           Y
# 9   LP001067    Male      No  ...            1.0     Semiurban           Y
# 10  LP001078    Male      No  ...            1.0         Urban           Y
# ...

# %%
df5=df4.dropna(axis=0)
df5
# Out:
#       Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0    LP001015   Male     Yes  ...            1.0         Urban           Y
# 1    LP001022   Male     Yes  ...            1.0         Urban           Y
# 2    LP001031   Male     Yes  ...            1.0         Urban           Y
# 4    LP001051   Male      No  ...            1.0         Urban           Y
# 5    LP001054   Male     Yes  ...            1.0         Urban           Y
# ..        ...    ...     ...  ...            ...           ...         ...
# 361  LP002969   Male     Yes  ...            1.0     Semiurban           Y
# 362  LP002971   Male     Yes  ...            1.0         Urban           Y
# 363  LP002975   Male     Yes  ...            1.0         Urban           Y
# 365  LP002986   Male     Yes  ...            1.0         Rural           Y
# 366  LP002989   Male      No  ...            1.0         Rural           Y
#
# [289 rows x 13 columns]

# %%
 from sklearn.model_selection import train_test_split

# %%
inputs=df5.drop(['Loan_Status'], axis='columns')
target=df5.Loan_Status

# %%
 from sklearn.preprocessing import LabelEncoder
le_Loan_ID= LabelEncoder()
le_Married= LabelEncoder()
le_Education= LabelEncoder()
le_ApplicantIncome= LabelEncoder()
le_CoapplicantIncome= LabelEncoder()
le_LoanAmount= LabelEncoder()
le_Property_Area=LabelEncoder()

# %%
 inputs['Loan_ID_n'] = le_Loan_ID.fit_transform(inputs['Loan_ID'])
inputs['Married_n'] = le_Married.fit_transform(inputs['Married'])
inputs['Education_n'] = le_Education.fit_transform(inputs['Education'])
inputs['ApplicantIncome_n'] = le_ApplicantIncome.fit_transform(inputs['ApplicantIncome'])
inputs['CoapplicantIncome_n'] = le_CoapplicantIncome.fit_transform(inputs['CoapplicantIncome'])
inputs['Property_Area_n'] = le_Property_Area.fit_transform(inputs['Property_Area'])

# %%
inputs
# Out:
#       Loan_ID Married  ... CoapplicantIncome_n  Property_Area_n
# 0    LP001015     Yes  ...                   0                2
# 1    LP001022     Yes  ...                  43                2
# 2    LP001031     Yes  ...                  67                2
# 3    LP001035     Yes  ...                 110                2
# 4    LP001051      No  ...                   0                2
# ..        ...     ...  ...                 ...              ...
# 362  LP002971     Yes  ...                  65                2
# 363  LP002975     Yes  ...                  12                2
# 364  LP002980      No  ...                  75                1
# 365  LP002986     Yes  ...                 101                0
# 366  LP002989      No  ...                   0                0
#
# [367 rows x 12 columns]

# %%
inputs_n=inputs.drop(['ApplicantIncome','CoapplicantIncome','Loan_ID','Education','Married','Property_Area'],axis='columns')
inputs_n
# Out:
#      Loan_ID_n  Married_n  ...  CoapplicantIncome_n  Property_Area_n
# 0            0          1  ...                    0                2
# 1            1          1  ...                   43                2
# 2            2          1  ...                   67                2
# 3            3          1  ...                  110                2
# 4            4          0  ...                    0                2
# ..         ...        ...  ...                  ...              ...
# 362        362          1  ...                   65                2
# 363        363          1  ...                   12                2
# 364        364          0  ...                   75                1
# 365        365          1  ...                  101                0
# 366        366          0  ...                    0                0
#
# [367 rows x 6 columns]

# %%
 x_train, x_test, y_train, y_test = train_test_split(inputs_n,target, test_size=0.2)

# %%
 from sklearn.svm import SVC
model = SVC()

# %%
 model.fit(x_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
 model.score(x_test, y_test)
# Out:
# 0.8243243243243243

# %%
y_test
# Out:
# 347    Y
# 207    Y
# 227    Y
# 3      Y
# 4      Y
#       ..
# 154    Y
# 290    Y
# 159    Y
# 54     Y
# 123    N
# Name: Loan_Status, Length: 74, dtype: object

# %% [markdown]
#  K-NEAREST NEIGHBOUR

# %%
 import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
 df6=pd.read_csv('test_AV3.csv')
df6.head(50)
# Out:
#      Loan_ID  Gender Married  ... Credit_History Property_Area Loan_Status
# 0   LP001015    Male     Yes  ...            1.0         Urban           Y
# 1   LP001022    Male     Yes  ...            1.0         Urban           Y
# 2   LP001031    Male     Yes  ...            1.0         Urban           Y
# 3   LP001035    Male     Yes  ...            NaN         Urban           Y
# 4   LP001051    Male      No  ...            1.0         Urban           Y
# 5   LP001054    Male     Yes  ...            1.0         Urban           Y
# 6   LP001055  Female      No  ...            1.0     Semiurban           Y
# 7   LP001056    Male     Yes  ...            0.0         Rural           N
# 8   LP001059    Male     Yes  ...            1.0         Urban           Y
# 9   LP001067    Male      No  ...            1.0     Semiurban           Y
# 10  LP001078    Male      No  ...            1.0         Urban           Y
# ...

# %%
df7=df6.dropna(axis=0)
df7
# Out:
#       Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0    LP001015   Male     Yes  ...            1.0         Urban           Y
# 1    LP001022   Male     Yes  ...            1.0         Urban           Y
# 2    LP001031   Male     Yes  ...            1.0         Urban           Y
# 4    LP001051   Male      No  ...            1.0         Urban           Y
# 5    LP001054   Male     Yes  ...            1.0         Urban           Y
# ..        ...    ...     ...  ...            ...           ...         ...
# 361  LP002969   Male     Yes  ...            1.0     Semiurban           Y
# 362  LP002971   Male     Yes  ...            1.0         Urban           Y
# 363  LP002975   Male     Yes  ...            1.0         Urban           Y
# 365  LP002986   Male     Yes  ...            1.0         Rural           Y
# 366  LP002989   Male      No  ...            1.0         Rural           Y
#
# [289 rows x 13 columns]

# %%
 inputs=df7.drop(['Loan_Status'], axis='columns')
target=df7.Loan_Status

# %%
 from sklearn.preprocessing import LabelEncoder
le_Loan_ID= LabelEncoder()
le_Married= LabelEncoder()
le_Education= LabelEncoder()
le_ApplicantIncome= LabelEncoder()
le_CoapplicantIncome= LabelEncoder()
le_LoanAmount= LabelEncoder()
le_Property_Area=LabelEncoder()
le_Gender= LabelEncoder()
le_Self_Employed=LabelEncoder()
le_Dependents=LabelEncoder()

# %%
 inputs['Loan_ID_n'] = le_Loan_ID.fit_transform(inputs['Loan_ID'])
inputs['Married_n'] = le_Married.fit_transform(inputs['Married'])
inputs['Education_n'] = le_Education.fit_transform(inputs['Education'])
inputs['ApplicantIncome_n'] = le_ApplicantIncome.fit_transform(inputs['ApplicantIncome'])
inputs['CoapplicantIncome_n'] = le_CoapplicantIncome.fit_transform(inputs['CoapplicantIncome'])
inputs['Property_Area_n'] = le_Property_Area.fit_transform(inputs['Property_Area'])
inputs['Gender_n'] = le_Gender.fit_transform(inputs['Gender'])
inputs['Self_Employed_n'] = le_Self_Employed.fit_transform(inputs['Self_Employed'])
inputs['Dependents_n'] = le_Dependents.fit_transform(inputs['Dependents'])

# %%
inputs
# Out:
#       Loan_ID Gender Married  ... Gender_n Self_Employed_n Dependents_n
# 0    LP001015   Male     Yes  ...        1               0            0
# 1    LP001022   Male     Yes  ...        1               0            1
# 2    LP001031   Male     Yes  ...        1               0            2
# 4    LP001051   Male      No  ...        1               0            0
# 5    LP001054   Male     Yes  ...        1               1            0
# ..        ...    ...     ...  ...      ...             ...          ...
# 361  LP002969   Male     Yes  ...        1               0            1
# 362  LP002971   Male     Yes  ...        1               1            3
# 363  LP002975   Male     Yes  ...        1               0            0
# 365  LP002986   Male     Yes  ...        1               0            0
# 366  LP002989   Male      No  ...        1               1            0
#
# [289 rows x 21 columns]

# %%
inputs_n=inputs.drop(['Self_Employed','Dependents','Gender','ApplicantIncome','CoapplicantIncome','Loan_ID','Education','Married','Property_Area'],axis='columns')
inputs_n
# Out:
#      LoanAmount  Loan_Amount_Term  ...  Self_Employed_n  Dependents_n
# 0         110.0             360.0  ...                0             0
# 1         126.0             360.0  ...                0             1
# 2         208.0             360.0  ...                0             2
# 4          78.0             360.0  ...                0             0
# 5         152.0             360.0  ...                1             0
# ..          ...               ...  ...              ...           ...
# 361        99.0             360.0  ...                0             1
# 362       113.0             360.0  ...                1             3
# 363       115.0             360.0  ...                0             0
# 365       158.0             360.0  ...                0             0
# 366        98.0             180.0  ...                1             0
#
# [289 rows x 12 columns]

# %%
target=df7.Loan_Status
target
# Out:
# 0      Y
# 1      Y
# 2      Y
# 4      Y
# 5      Y
#       ..
# 361    Y
# 362    Y
# 363    Y
# 365    Y
# 366    Y
# Name: Loan_Status, Length: 289, dtype: object

# %%
 from sklearn.preprocessing import StandardScaler

# %%
 scaler = StandardScaler()

# %%
 scaler.fit(inputs_n)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
 scaled_features = scaler.transform(inputs_n)

# %%
df_feat = pd.DataFrame(scaled_features,columns=df7.columns[:-1])
df_feat.head()
# Out:
#     Loan_ID    Gender  ...  Credit_History  Property_Area
# 0 -0.449565  0.264392  ...       -0.352865      -0.756122
# 1 -0.181092  0.264392  ...       -0.352865       0.185771
# 2  1.194835  0.264392  ...       -0.352865       1.127664
# 3 -0.986512  0.264392  ...       -0.352865      -0.756122
# 4  0.255178  0.264392  ...        2.833946      -0.756122
#
# [5 rows x 12 columns]

# %%
 import seaborn as sns
 
sns.pairplot(df7,hue='Loan_Status')

# %%
 from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(scaled_features,df7['Loan_Status'],
                                                    test_size=0.30)

# %%
 from sklearn.neighbors import KNeighborsClassifier

# %%
 knn = KNeighborsClassifier(n_neighbors=20)

# %%
 knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#                      weights='uniform')

# %%
 pred = knn.predict(X_test)
pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y'], dtype=object)

# %%
 knn.score(X_test,y_test)
# Out:
# 0.9770114942528736
